# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import networkx as nx
import matplotlib.pyplot as plt
import pickle
import math
import os
import sys

# current_dir = os.path.dirname(os.path.abspath(__file__))
current_dir = os.getcwd()
project_root = os.path.dirname(current_dir)
sys.path.append(project_root)

from Auxiliary_Functions.Reading_Instances import read_instance_from_dat
from MIP_Models.MIP import solve_flow_aware_location_decisions, solve_all_or_routing_decisions
from MIP_Models.MIPs import solve_location_decisions, solve_routing_decisions
from Auxiliary_Functions.extracting_solution_features import extract_OFV_solution_features

# %%
def main(data_folders, ml_input_file, heuristic_output_folder):
    # Load the ML combined input file
    try:
        ml_combined_data = pd.read_csv(ml_input_file)
    except FileNotFoundError:
        print(f"Error: File '{ml_input_file}' not found. Please check the path.")
        return

    # Extract unique instance IDs
    unique_instance_ids = ml_combined_data["Instance ID"].unique()

    # Create heuristic output folder if it doesn't exist
    os.makedirs(heuristic_output_folder, exist_ok=True)

    # Dynamically create the output file name based on the input file
    input_csv_name = os.path.basename(ml_input_file)
    output_csv_name = f"Heuristic_output_{input_csv_name}"
    output_file = os.path.join(heuristic_output_folder, output_csv_name)

    # Define CSV column structure
    columns = [
        "Instance ID", "use_ml_guidance", "use_location_first", "use_ML_direct", "use_ML_transhipment",
        "ML_Optimization status", "ML_Optimality Gap", "ML_OFV - Total Costs", "ML_Total Solving Time",
        "Stage 1 Feasibility", "Stage 2 Feasibility"
    ]

    # Create the output file if it doesn’t exist
    if not os.path.exists(output_file):
        pd.DataFrame(columns=columns).to_csv(output_file, index=False)

    # Define all configurations for solving
    configurations = [
        (False, False, False, False),# No ML guidance, no location first
        # (False, True, False, False),# No ML guidance, location first**
        (True, False, True, True),  # ML-guided (both, no location first)
        (True, False, True, False), # ML-guided (direct only, no location first)
        (True, False, False, True), # ML-guided (transshipment only, no location first)
        # (True, True, True, False),   # ML-guided (direct only, location first)**
        # (True, True, False, True),  # ML-guided (transshipment only, location first)**
        # (True, True, True, True),   # ML-guided (both, location first)**
    ]

    # Loop through each instance
    for instance_id in unique_instance_ids:
        # Search for the instance file in the data folders
        instance_file = None
        for folder in data_folders:
            potential_path = os.path.join(folder, f"{instance_id}.dat")
            if os.path.isfile(potential_path):
                instance_file = potential_path
                break

        if instance_file is None:
            print(f"Instance file '{instance_id}.dat' not found in any data folder.")
            continue

        print(f"Processing instance: {instance_id}")

        # Load instance data
        instance_data = read_instance_from_dat(instance_file)

        # Filter ML data for the current instance
        ml_data = ml_combined_data[ml_combined_data["Instance ID"] == instance_id]

        # Loop through each configuration
        for use_ml_guidance, use_location_first, use_ML_direct, use_ML_transhipment in configurations:
            # Ensure at least one of use_ML_direct or use_ML_transhipment is True if use_ml_guidance is True
            if use_ml_guidance and not (use_ML_direct or use_ML_transhipment):
                print("Skipping invalid configuration.")
                continue

            print(f"Configuration: use_ml_guidance={use_ml_guidance}, use_location_first={use_location_first}, "
                  f"use_ML_direct={use_ML_direct}, use_ML_transhipment={use_ML_transhipment}")

            fixed_hubs = []  # Default value if not solving location decisions
            stage1_status = "Not Solved"
            stage2_status = "Not Solved"
            optimization_status = None
            optimality_gap = None
            objective_value = None
            solving_time = None

            # Stage 1: Solve flow-aware location decisions
            if use_location_first:
                print("Solving location decisions...")
                fixed_hubs,sln_count,flag = solve_location_decisions(instance_data, ml_data, use_ml_guidance,use_ML_direct, use_ML_transhipment)
                if sln_count > 0:
                    stage1_status = "Feasible"
                elif not flag:
                    stage1_status = "Feasible-Not Solved"
                    
                elif sln_count == 0 and flag:
                    stage1_status = "Infeasible"
                
            else:
                print("Skipping location decisions... Using all hubs as candidates.")
                fixed_hubs = list(range(1, int(instance_data.S) + 1))  # Use all hubs as candidates
                stage1_status = "Skipped"

            # Stage 2: Solve routing decisions
            try:
                print("Solving routing decisions...")
                result = solve_routing_decisions(
                    instance_data, ml_data, fixed_hubs, use_ml_guidance, use_location_first, use_ML_direct, use_ML_transhipment
                )

                if result['status'] in [GRB.OPTIMAL, GRB.TIME_LIMIT]:
                    stage2_status = "Feasible"
                    optimization_status = "Optimal" if result['status'] == GRB.OPTIMAL else "Time Limit"
                    optimality_gap = result.get("optimality_gap", None)
                    objective_value = result.get("objective_value", None)
                    solving_time = result.get("total_solving_time", None)

                else:
                    stage2_status = "Infeasible"
                    optimization_status = "Infeasible"

            except Exception as e:
                print(f"Error in Stage 2: {e}")
                stage2_status = "Error"
                optimization_status = "Error"

            # Create a row of results
            result_row = {
                "Instance ID": instance_id,
                "use_ml_guidance": use_ml_guidance,
                "use_location_first": use_location_first,
                "use_ML_direct": use_ML_direct,
                "use_ML_transhipment": use_ML_transhipment,
                "ML_Optimization status": optimization_status,
                "ML_Optimality Gap": optimality_gap,
                "ML_OFV - Total Costs": objective_value,
                "ML_Total Solving Time": solving_time,
                "Stage 1 Feasibility": stage1_status,
                "Stage 2 Feasibility": stage2_status
            }

            # Append to the CSV
            pd.DataFrame([result_row]).to_csv(output_file, mode='a', header=False, index=False)

            print(f"Saved configuration result for instance: {instance_id}")

    print(f"All results saved to {output_file}")

# %%
if __name__ == "__main__":
    # Define data folders to search for instance files
    data_folders = [
        "DATA/Luisa Data",
        "DATA/Modified/Flow Modifications",
        "DATA/Modified/Hub Cost Modifications",
        "DATA/Modified/BOTH",
    ]

    # Path to the ML combined output file
    ml_input_file = "ML Experiments/XG_BOOST Predictions/ML_combined_output_features_1.csv"

    # Path to the heuristic output folder
    heuristic_output_folder = "ML Experiments/Heuristic Results"

    # Run the main function
    main(data_folders, ml_input_file, heuristic_output_folder)
# Out:
# Processing instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=False, use_ML_direct=False, use_ML_transhipment=False
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 12238 rows, 31659 columns and 67204 nonzeros
# Model fingerprint: 0xe5841327
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 120 rows and 108 columns
# Presolve time: 0.06s
# Presolved: 12118 rows, 31551 columns, 66976 nonzeros
# Variable types: 0 continuous, 31551 integer (31551 binary)
#
# Root relaxation: objective 3.307391e+04, 11334 iterations, 0.78 seconds (2.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33073.9129    0  265          - 33073.9129      -     -    1s
# H    0     0                    52766.260000 33073.9129  37.3%     -    1s
#      0     0 50224.8280    0  495 52766.2600 50224.8280  4.82%     -    2s
# H    0     0                    50386.930000 50224.8280  0.32%     -    2s
#      0     0 50224.8284    0  472 50386.9300 50224.8284  0.32%     -    2s
#      0     0 50224.8284    0  467 50386.9300 50224.8284  0.32%     -    2s
#      0     0 50224.8284    0  194 50386.9300 50224.8284  0.32%     -    2s
#      0     0 50224.8284    0  419 50386.9300 50224.8284  0.32%     -    3s
#      0     0 50224.8284    0  404 50386.9300 50224.8284  0.32%     -    3s
#      0     0 50224.8284    0  428 50386.9300 50224.8284  0.32%     -    3s
# H    0     0                    50335.090000 50224.8284  0.22%     -    3s
#      0     0 50224.8284    0  400 50335.0900 50224.8284  0.22%     -    3s
#      0     0 50230.4818    0   68 50335.0900 50230.4818  0.21%     -    3s
#      0     0 50230.4818    0   43 50335.0900 50230.4818  0.21%     -    3s
#      0     0 50230.4818    0  252 50335.0900 50230.4818  0.21%     -    3s
#      0     0 50230.4818    0   39 50335.0900 50230.4818  0.21%     -    3s
#      0     0 50230.4818    0   39 50335.0900 50230.4818  0.21%     -    4s
# H    0     0                    50230.510000 50230.4818  0.00%     -    4s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 5
#   Clique: 12
#   MIR: 5
#   StrongCG: 1
#   GUB cover: 7
#   Zero half: 8
#   RLT: 4
#   Lazy constraints: 2
#
# Explored 1 nodes (33799 simplex iterations) in 4.02 seconds (7.71 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 4: 50230.5 50335.1 50386.9 52766.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.023051000000e+04, best bound 5.023048176471e+04, gap 0.0001%
#
# User-callback calls 878, time in user-callback 0.01 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 4)
#   Arc (1, 5)
#   Arc (2, 6)
#   Arc (3, 7)
#   Arc (4, 2)
#   Arc (5, 3)
#   Arc (6, 8)
#   Arc (7, 0)
#   Arc (8, 1)
# Vehicle 1:
# Vehicle 2:
# Vehicle 3:
#   Arc (0, 7)
#   Arc (2, 4)
#   Arc (4, 0)
#   Arc (7, 2)
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 12874 rows, 31659 columns and 71620 nonzeros
# Model fingerprint: 0xd086f59c
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 252 rows and 240 columns
# Presolve time: 0.06s
# Presolved: 12622 rows, 31419 columns, 70644 nonzeros
# Variable types: 0 continuous, 31419 integer (31419 binary)
#
# Root relaxation: objective 3.349189e+04, 16636 iterations, 1.60 seconds (4.36 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0
work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 1: 78956.3
#
# Time limit reached
# Best objective 7.895631000000e+04, best bound 3.868827965716e+04, gap 51.0004%
#
# User-callback calls 128713, time in user-callback 0.13 sec
# Model solved with status 9.
# Model solved with status 9.
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=False
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 13066 rows, 31659 columns and 74764 nonzeros
# Model fingerprint: 0xef294375
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 444 rows and 108 columns
# Presolve time: 0.06s
# Presolved: 12622 rows, 31551 columns, 69676 nonzeros
# Variable types: 0 continuous, 31551 integer (31551 binary)
#
# Root relaxation: objective 3.307391e+04, 14907 iterations, 1.47 seconds (3.66 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33073.9129    0  389          - 33073.9129      -     -    1s
# H    0     0                    50829.460000 33073.9129  34.9%     -    1s
#      0     0 48777.2284    0  890 50829.4600 48777.2284  4.04%     -    4s
# H    0     0                    50445.040000 48777.2284  3.31%     -    4s
#      0     0 48936.8232    0  507 50445.0400 48936.8232  2.99%     -    6s
#      0     0 49022.4186    0 1035 50445.0400 49022.4186  2.82%     -    8s
#      0     0 49024.5159    0  690 50445.0400 49024.5159  2.82%     -    8s
#      0     0 49024.5159    0  861 50445.0400 49024.5159  2.82%     -    9s
#      0     0 49024.5159    0 1302 50445.0400 49024.5159  2.82%     -   10s
#      0     0 49024.5159    0  823 50445.0400 49024.5159  2.82%     -   10s
#      0     0 49041.0784    0  510 50445.0400 49041.0784  2.78%     -   12s
#      0     0 49041.0784    0  813 50445.0400 49041.0784  2.78%     -   12s
#      0     0 49041.0784    0  777 50445.0400 49041.0784  2.78%     -   12s
#      0     0 49041.0784    0  490 50445.0400 49041.0784  2.78%     -   13s
#      0     0 49041.0784    0 1024 50445.0400 49041.0784  2.78%     -   13s
#      0     0 49041.0784    0  557 50445.0400 49041.0784  2.78%     -   14s
#      0     0 49041.0784    0  510 50445.0400 49041.0784  2.78%     -   14s
#      0     2 49041.0784    0  510 50445.0400 49041.0784  2.78%     -   15s
#     15     6 50230.5100    6  250 50445.0400 50230.4813  0.43%  4524   21s
# H   78    22                    50438.500000 50245.4599  0.38%  2126   22s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 13
#   Clique: 15
#   MIR: 1
#   StrongCG: 1
#   GUB cover: 10
#   Zero half: 21
#   RLT: 6
#   Lazy constraints: 1
#
# Explored 236 nodes (281898 simplex iterations) in 23.63 seconds (63.97 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 3: 50438.5 50445 50829.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.043850000000e+04, best bound 5.043850000000e+04, gap 0.0000%
#
# User-callback calls 5103, time in user-callback 0.01 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
# Vehicle 1:
# Vehicle 2:
#   Arc (0, 5)
#   Arc (1, 8)
#   Arc (2, 4)
#   Arc (4, 0)
#   Arc (5, 1)
#   Arc (6, 7)
#   Arc (7, 2)
#   Arc (8, 6)
# Vehicle 3:
#   Arc (0, 4)
#   Arc (2, 3)
#   Arc (3, 5)
#   Arc (4, 2)
#   Arc (5, 0)
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=False, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 12046 rows, 31659 columns and 64060 nonzeros
# Model fingerprint: 0xa76d973f
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 252 rows and 240 columns
# Presolve time: 0.05s
# Presolved: 11794 rows, 31419 columns, 63084 nonzeros
# Variable types: 0 continuous, 31419 integer (31419 binary)
#
# Root relaxation: objective 3.349189e+04, 11422 iterations, 0.78 seconds (2.13 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33491.8859    0  553          - 33491.8859      -     -    1s
# H    0     0                    53782.960000 33491.8859  37.7%     -    1s
#      0     0 35652.9979    0 1631 53782.9600 35652.9979  33.7%     -    6s
#      0     0 35758.5075    0 1566 53782.9600 35758.5075  33.5%     -    7s
#      0     0 35771.2707    0 1641 53782.9600 35771.2707  33.5%     -    8s
#      0     0 35771.3537    0 1654 53782.9600 35771.3537  33.5%     -    8s
#      0     0 35771.3537    0 1812 53782.9600 35771.3537  33.5%     -    9s
#      0     0 35771.3537    0 1775 53782.9600 35771.3537  33.5%     -    9s
#      0     0 35784.1699    0 1685 53782.9600 35784.1699  33.5%     -   10s
#      0     0 35784.5108    0 1658 53782.9600 35784.5108  33.5%     -   11s
#      0     0 35802.3426    0 1285 53782.9600 35802.3426  33.4%     -   11s
#      0     0 35802.9159    0 1273 53782.9600 35802.9159  33.4%     -   13s
#      0     0 35803.0706    0 1302 53782.9600 35803.0706  33.4%     -   13s
#      0     0 35803.0706    0 1399 53782.9600 35803.0706  33.4%     -   13s
#      0     0 35811.7473    0 1288 53782.9600 35811.7473  33.4%     -   15s
#      0     0 35812.3377    0 1234 53782.9600 35812.3377  33.4%     -   15s
#      0     0 35812.3377    0 1232 53782.9600 35812.3377  33.4%     -   15s
#      0     0 35831.0329    0 1322 53782.9600 35831.0329  33.4%     -   16s
#      0     0 35836.0087    0 1344 53782.9600 35836.0087  33.4%     -   17s
#      0     0 35836.0087    0 1315 53782.9600 35836.0087  33.4%     -   17s
#      0     0 35891.1393    0 1343 53782.9600 35891.1393  33.3%     -   18s
#      0     0 35893.0226    0 1420 53782.9600 35893.0226  33.3%     -   19s
#      0     0 43094.7173    0 1292 53782.9600 43094.7173  19.9%     -   42s
#      0     0 43128.8498    0 1336 53782.9600 43128.8498  19.8%     -   43s
#      0     0 43131.6767    0 1320 53782.9600 43131.6767  19.8%     -   43s
#      0     0 43495.0522    0 1276 53782.9600 43495.0522  19.1%     -   43s
#      0     0 43533.8108    0 1345 53782.9600 43533.8108  19.1%     -   44s
#      0     0 43533.8108    0 1345 53782.9600 43533.8108  19.1%     -   44s
#      0     0 43693.7552    0 1303 53782.9600 43693.7552  18.8%     -   45s
#      0     0 43707.4591    0 1302 53782.9600 43707.4591  18.7%     -   46s
#      0     0 43710.6266    0 1275 53782.9600 43710.6266  18.7%     -   46s
#      0     0 43710.6266    0 1277 53782.9600 43710.6266  18.7%     -   46s
#      0     0 43764.9925    0 1293 53782.9600 43764.9925  18.6%     -   46s
#      0     0 43773.8110    0 1365 53782.9600 43773.8110  18.6%     -   47s
#      0     0 43774.0170    0 1349 53782.9600 43774.0170  18.6%     -   47s
#      0     0 43807.7435    0 1312 53782.9600 43807.7435  18.5%     -   47s
#      0     0 43808.1383    0 1329 53782.9600 43808.1383  18.5%     -   48s
#      0     0 44064.8800    0 1334 53782.9600 44064.8800  18.1%     -   48s
#      0     0 44071.3163    0 1314 53782.9600 44071.3163  18.1%     -   50s
#      0     0 44074.6591    0 1312 53782.9600 44074.6591  18.1%     -   50s
#      0     0 44074.7059    0 1329 53782.9600 44074.7059  18.1%     -   50s
#      0     0 44114.9835    0 1339 53782.9600 44114.9835  18.0%     -   50s
#      0     0 44115.2114    0 1333 53782.9600 44115.2114  18.0%     -   51s
#      0     0 44115.2114    0 1337 53782.9600 44115.2114  18.0%     -   51s
#      0     0 44115.2114    0 1195 53782.9600 44115.2114  18.0%     -   53s
#      0     2 44115.2114    0 1195 53782.9600 44115.2114  18.0%     -   54s
#      3     8 45167.2189    2  854 53782.9600 44378.5068  17.5%  4748   55s
# *  179   120              15    53688.010000 50328.3022  6.26%  1519   59s
#    196   119 53484.4235   12  206 53688.0100 50328.3022  6.26%  1409   60s
#    323   146 52039.2472    9  406 53688.0100 50435.0360  6.06%  1166   65s
#    910   257 52302.9755   19  560 53688.0100 50566.6918  5.81%   855   70s
#   1599   393 52898.3102   27  526 53688.0100 51483.9394  4.11%   803   75s
#   2738   206     cutoff   13      53688.0100 52618.8541  1.99%   733   80s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 4
#   GUB cover: 1
#   Zero half: 121
#   RLT: 92
#
# Explored 3346 nodes (2338458 simplex iterations) in 81.19 seconds (222.51 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 2: 53688 53783
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.368801000000e+04, best bound 5.368801000000e+04, gap 0.0000%
#
# User-callback calls 35856, time in user-callback 0.05 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 2)
#   Arc (1, 8)
#   Arc (2, 7)
#   Arc (3, 5)
#   Arc (5, 1)
#   Arc (6, 0)
#   Arc (7, 3)
#   Arc (8, 6)
# Vehicle 1:
#   Arc (0, 3)
#   Arc (1, 6)
#   Arc (2, 4)
#   Arc (3, 5)
#   Arc (4, 7)
#   Arc (5, 1)
#   Arc (6, 2)
#   Arc (7, 0)
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Processing instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=False, use_ML_direct=False, use_ML_transhipment=False
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 11478 rows, 31659 columns and 62988 nonzeros
# Model fingerprint: 0x6b368934
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 592 rows and 332 columns
# Presolve time: 0.06s
# Presolved: 10886 rows, 31327 columns, 66880 nonzeros
# Variable types: 0 continuous, 31327 integer (31327 binary)
#
# Root relaxation: objective 5.360111e+04, 8929 iterations, 0.62 seconds (1.46 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 53601.1119    0  330          - 53601.1119      -     -    1s
#      0     0 68268.1134    0  161          - 68268.1134      -     -    2s
#      0     0 68268.1134    0  334          - 68268.1134      -     -    2s
#      0     0 68268.1134    0  416          - 68268.1134      -     -    2s
#      0     0 68449.3032    0  337          - 68449.3032      -     -    3s
#      0     0 68449.3032    0  315          - 68449.3032      -     -    3s
#      0     0 68449.3032    0  522          - 68449.3032      -     -    3s
# H    0     0                    135170.88000 68449.3032  49.4%     -    3s
# H    0     0                    132997.38000 68449.3032  48.5%     -    3s
#      0     0 68798.9948    0  723 132997.380 68798.9948  48.3%     -    3s
#      0     0 68798.9948    0  366 132997.380 68798.9948  48.3%     -    4s
# H    0     0                    123869.08500 68798.9948  44.5%     -    4s
#      0     0 68798.9948    0  478 123869.085 68798.9948  44.5%     -    4s
#      0     0 68798.9948    0  663 123869.085 68798.9948  44.5%     -    4s
#      0     0 68798.9948    0  365 123869.085 68798.9948  44.5%     -    4s
# H    0     0                    111742.08000 68798.9948  38.4%     -    4s
#      0     0 68798.9948    0  629 111742.080 68798.9948  38.4%     -    4s
#      0     0 68798.9948    0  405 111742.080 68798.9948  38.4%     -    5s
#      0     0 68798.9948    0  605 111742.080 68798.9948  38.4%     -    5s
#      0     0 68798.9948    0  370 111742.080 68798.9948  38.4%     -    5s
#      0     0 68798.9948    0  368 111742.080 68798.9948  38.4%     -    5s
# H    0     0                    105373.60500 68798.9948  34.7%     -    5s
#      0     2 68798.9948    0  367 105373.605 68798.9948  34.7%     -    6s
# H   30    44                    85345.720000 68835.1830  19.3%   970    7s
# H   31    44                    74172.265000 68835.1830  7.20%   974    7s
# *  142   128              11    73389.610000 68835.1830  6.21%   578    8s
#    345   194 69920.4775    7  250 73389.6100 68879.0462  6.15%   407   11s
# H  352   194                    73308.025000 68879.0462  6.04%   401   11s
# *  811   353              17    72820.300000 68902.4320  5.38%   302   12s
# * 1021   448              14    72670.645000 69137.5382  4.86%   291   14s
#   1359   504     cutoff   17      72670.6450 69162.8721  4.83%   261   15s
# * 2596   753              15    72583.525000 70489.2977  2.89%   233   17s
#   3834   904 71907.6587   12  159 72583.5250 70672.5514  2.63%   220   23s
#   5230  1055     cutoff   16      72583.5250 70780.3894  2.48%   205   25s
#  10149  1010 72126.3025   13  169 72583.5250 71307.4638  1.76%   184   30s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 11
#   MIR: 14
#   StrongCG: 2
#   GUB cover: 2
#   Zero half: 9
#   Lazy constraints: 110
#
# Explored 14543 nodes (2495746 simplex iterations) in 33.12 seconds (87.40 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 72583.5 72670.6 72820.3 ... 123869
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.258352500000e+04, best bound 7.258352500000e+04, gap 0.0000%
#
# User-callback calls 36327, time in user-callback 0.11 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
# Vehicle 1:
# Vehicle 2:
#   Arc (0, 8)
#   Arc (1, 3)
#   Arc (3, 0)
#   Arc (5, 1)
#   Arc (8, 5)
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
#   Arc (0, 5)
#   Arc (1, 8)
#   Arc (2, 6)
#   Arc (3, 7)
#   Arc (4, 2)
#   Arc (5, 3)
#   Arc (6, 1)
#   Arc (7, 4)
#   Arc (8, 0)
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 11802 rows, 31659 columns and 65916 nonzeros
# Model fingerprint: 0xeffb9a00
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 744 rows and 488 columns
# Presolve time: 0.07s
# Presolved: 11058 rows, 31171 columns, 68524 nonzeros
# Variable types: 0 continuous, 31171 integer (31171 binary)
#
# Root relaxation: objective 5.684430e+04, 11027 iterations, 0.84 seconds (1.98 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 56844.2972    0  786          - 56844.2972      -     -    1s
# H    0     0                    96994.870000 56844.2972  41.4%     -    1s
#      0     0 57743.1738    0  970 96994.8700 57743.1738  40.5%     -    4s
#      0     0 57745.2085    0  930 96994.8700 57745.2085  40.5%     -    5s
#      0     0 58176.6726    0 1031 96994.8700 58176.6726  40.0%     -    5s
#      0     0 58185.7377    0  999 96994.8700 58185.7377  40.0%     -    5s
#      0     0 58267.0211    0 1002 96994.8700 58267.0211  39.9%     -    5s
#      0     0 58288.1852    0 1195 96994.8700 58288.1852  39.9%     -    5s
#      0     0 58288.1852    0 1115 96994.8700 58288.1852  39.9%     -    5s
#      0     0 59721.9217    0 1048 96994.8700 59721.9217  38.4%     -    6s
#      0     0 59722.6044    0 1041 96994.8700 59722.6044  38.4%     -    7s
#      0     0 60724.4046    0 1219 96994.8700 60724.4046  37.4%     -    8s
#      0     0 61002.8485    0 1046 96994.8700 61002.8485  37.1%     -   10s
#      0     0 61389.9990    0 1235 96994.8700 61389.9990  36.7%     -   10s
#      0     0 61391.5209    0 1214 96994.8700 61391.5209  36.7%     -   10s
#      0     0 63827.6869    0 1047 96994.8700 63827.6869  34.2%     -   11s
# *  948   643              26    88185.700000 69623.5019  21.0%   891   67s
# *  956   644              29    87055.795000 69623.5019  20.0%   886   67s
#   1259   763     cutoff   28      87055.7950 69623.5019  20.0%   838   70s
#   2059  1007 76705.1385   11  543 87055.7950 73829.6222  15.2%   773   75s
#   2859  1273     cutoff   15      87055.7950 74546.0444  14.4%   732   80s
#   3637  1464 86655.3479   15  697 87055.7950 75107.9566  13.7%   713   85s
#   4251  1612 87023.2675   28  588 87055.7950 75225.5582  13.6%   704   93s
#   4253  1614 76553.7937   12  845 87055.7950 75225.5582  13.6%   703   95s
#   4256  1616 84195.0036   22 1317 87055.7950 75225.5582  13.6%   703  100s
#   4260  1618 86631.2700   14 1336 87055.7950 75225.5582  13.6%   702  107s
#   4295  1633 75225.5582   21  681 87055.7950 75225.5582  13.6%   724  110s
#   4688  1641 80416.3416   36  263 87055.7950 75225.5582  13.6%   736  119s
#   4835  1656 78191.3785   23  336 87055.7950 75225.5582  13.6%   729  120s
# * 5191  1556              38    86954.935000 75225.5582  13.5%   709  121s
# * 5911  1430              40    85682.215000 79031.9443  7.76%   668  122s
#   6760  1310 82288.3510   30  545 85682.2150 79187.4712  7.58%   625  125s
#   6876  1278 infeasible   30      85682.2150 79187.4712  7.58%   620  130s
# * 7247  1092              32    85581.280000 79603.9613  6.98%   605  131s
#
# Cutting planes:
#   Inf proof: 10
#   Zero half: 20
#   RLT: 4
#   Lazy constraints: 12
#
# Explored 10383 nodes (5247996 simplex iterations) in 134.43 seconds (427.27 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 6: 85581.3 85682.2 86954.9 ... 96994.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.558128000000e+04, best bound 8.558128000000e+04, gap 0.0000%
#
# User-callback calls 60003, time in user-callback 0.11 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 5)
#   Arc (1, 7)
#   Arc (2, 6)
#   Arc (3, 4)
#   Arc (4, 0)
#   Arc (5, 2)
#   Arc (6, 8)
#   Arc (7, 3)
#   Arc (8, 1)
# Vehicle 1:
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
#   Arc (0, 4)
#   Arc (1, 7)
#   Arc (2, 1)
#   Arc (3, 0)
#   Arc (4, 2)
#   Arc (5, 8)
#   Arc (7, 5)
#   Arc (8, 3)
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=False
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 11754 rows, 31659 columns and 65508 nonzeros
# Model fingerprint: 0x95b37a3b
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 700 rows and 332 columns
# Presolve time: 0.07s
# Presolved: 11054 rows, 31327 columns, 67580 nonzeros
# Variable types: 0 continuous, 31327 integer (31327 binary)
#
# Root relaxation: objective 5.390191e+04, 9542 iterations, 0.64 seconds (1.61 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 53901.9108    0  323          - 53901.9108      -     -    1s
#      0     0 62479.1107    0  659          - 62479.1107      -     -    2s
# H    0     0                    110420.30500 62479.1107  43.4%     -    2s
#      0     0 62479.2561    0  967 110420.305 62479.2561  43.4%     -    2s
#      0     0 62566.7529    0  825 110420.305 62566.7529  43.3%     -    3s
# H    0     0                    106685.80000 62566.7529  41.4%     -    3s
#      0     0 62571.2897    0 1080 106685.800 62571.2897  41.3%     -    3s
#      0     0 62571.2897    0  980 106685.800 62571.2897  41.3%     -    3s
#      0     0 62579.5786    0  975 106685.800 62579.5786  41.3%     -    4s
# H    0     0                    97852.480000 62579.5786  36.0%     -    4s
#      0     0 62579.5786    0  932 97852.4800 62579.5786  36.0%     -    5s
#      0     0 62579.5786    0  743 97852.4800 62579.5786  36.0%     -    5s
#      0     2 62579.5786    0  689 97852.4800 62579.5786  36.0%     -    6s
# H   41    42                    97424.125000 62761.1653  35.6%  1373    7s
# H  124   137                    96229.600000 62761.1653  34.8%  1013    8s
# H  125   137                    95652.970000 62761.1653  34.4%  1013    8s
# *  165   157              11    77347.975000 62761.1653  18.9%   942    8s
# *  166   157              11    75757.495000 62761.1653  17.2%   937    8s
# *  180   167              12    74951.380000 62761.1653  16.3%   911    8s
# H  253   196                    72749.500000 62761.1653  13.7%   795    9s
#    299   196 71705.2558   16  174 72749.5000 62761.1653  13.7%   783   10s
# H  305   196                    72681.550000 62761.1653  13.6%   788   10s
#    359   231     cutoff   19      72681.5500 62761.1653  13.6%   748   15s
# * 1791   436              18    72670.645000 63183.6645  13.1%   489   19s
#   1838   441 71863.4950   18  117 72670.6450 63579.7177  12.5%   486   20s
# * 1919   441              13    72583.525000 63633.6484  12.3%   485   20s
#   2957   568 70503.6700   12  113 72583.5250 65280.1003  10.1%   436   28s
#   3958   683 71871.8350   14   69 72583.5250 70618.1160  2.71%   386   30s
#   9444    68 72330.9138   21  200 72583.5250 71712.0819  1.20%   274   35s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 3
#   MIR: 1
#   StrongCG: 1
#   Zero half: 9
#   RLT: 3
#   Lazy constraints: 69
#
# Explored 10332 nodes (2729580 simplex iterations) in 35.57 seconds (103.44 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 72583.5 72670.6 72681.6 ... 97424.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.258352500000e+04, best bound 7.258352500000e+04, gap 0.0000%
#
# User-callback calls 31145, time in user-callback 0.07 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
# Vehicle 1:
#   Arc (0, 8)
#   Arc (1, 3)
#   Arc (3, 0)
#   Arc (5, 1)
#   Arc (8, 5)
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
#   Arc (0, 5)
#   Arc (1, 8)
#   Arc (2, 6)
#   Arc (3, 7)
#   Arc (4, 2)
#   Arc (5, 3)
#   Arc (6, 1)
#   Arc (7, 4)
#   Arc (8, 0)
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=False, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23
#  672371  9833 81797.7550   36  188 85460.7368 81487.0375  4.65%   414 2835s
#  675735  8707 84833.8132   47  371 85460.7368 81646.8400  4.46%   414 2842s
#  677583  8156 infeasible   31      85460.7368 81790.1687  4.30%   413 2845s
#  681083  7021 83823.9175   46  302 85460.7368 82022.3350  4.02%   412 2851s
#  684529  5783 85153.8030   31  279 85460.7368 82262.3050  3.74%   411 2856s
#  688027  4435 84355.6675   40  207 85460.7368 82595.3750  3.35%   410 2862s
#  689813  3670 84319.4875   36  245 85460.7368 82801.5775  3.11%   410 2865s
#  693435  1843     cutoff   39      85460.7368 83331.4917  2.49%   409 2870s
#
# Cutting planes:
#   Gomory: 16
#   Lift-and-project: 2
#   Cover: 79
#   MIR: 113
#   StrongCG: 6
#   Flow cover: 46
#   Inf proof: 13
#   Zero half: 45
#   RLT: 48
#   Lazy constraints: 172
#
# Explored 697295 nodes (283886469 simplex iterations) in 2873.68 seconds (8606.78 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 2: 85460.7 85460.7
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.546073678234e+04, best bound 8.546073678234e+04, gap 0.0000%
#
# User-callback calls 1990113, time in user-callback 3.05 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
# Vehicle 1:
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
#   Arc (0, 2)
#   Arc (1, 5)
#   Arc (2, 4)
#   Arc (3, 7)
#   Arc (4, 9)
#   Arc (5, 3)
#   Arc (6, 8)
#   Arc (7, 0)
#   Arc (8, 1)
#   Arc (9, 6)
# Vehicle 5:
#   Arc (0, 7)
#   Arc (2, 0)
#   Arc (7, 2)
# Optimal solution found.
# Model solved with status 2.
# Saved configuration result for instance: 9R-alpha=021_Flow_60perc_HubCosts_20perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 24966 rows, 49276 columns and 139560 nonzeros
# Model fingerprint: 0x5fe4713d
# Variable types: 0 continuous, 49276 integer (49276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 764 rows and 696 columns
# Presolve time: 0.12s
# Presolved: 24202 rows, 48580 columns, 134956 nonzeros
# Variable types: 0 continuous, 48580 integer (48580 binary)
# Root relaxation presolved: 24202 rows, 48580 columns, 134956 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.481601e+04, 12528 iterations, 1.14 seconds (2.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 54816.0073    0 2517          - 54816.0073      -     -    2s
#      0     0 55877.1300    0  735          - 55877.1300      -     -   10s
#      0     0 55994.6974    0 1922          - 55994.6974      -     -   46s
#      0     0 55994.6974    0 1948          - 55994.6974      -     -   48s
#      0     0 55994.6974    0 1948          - 55994.6974      -     -   61s
#      0     0 55994.6974    0 1948          - 55994.6974      -     -   72s
# H    0     0                    118340.44500 55994.6974  52.7%     -   86s
#      0     0 55994.6974    0 1951 118340.445 55994.6974  52.7%     -   87s
#      0     0 55994.6974    0 2013 118340.445 55994.6974  52.7%     -   88s
# H    0     0                    115808.73000 55994.6974  51.6%     -  111s
#      0     0 55994.6974    0 2009 115808.730 55994.6974  51.6%     -  111s
#      0     0 55994.6974    0 1865 115808.730 55994.6974  51.6%     -  115s
#      0     0 55994.6974    0 1879 115808.730 55994.6974  51.6%     -  122s
#      0     0 55994.6974    0 1936 115808.730 55994.6974  51.6%     -  123s
#      0     0 55994.6974    0 1780 115808.730 55994.6974  51.6%     -  126s
#      0     0 55994.6974    0 1780 115808.730 55994.6974  51.6%     -  134s
#      0     2 55994.6974    0 1780 115808.730 55994.6974  51.6%     -  142s
#      1     4 56010.2427    1 1260 115808.730 55994.6974  51.6% 238264  227s
#      3     6 56010.2427    2 1278 115808.730 55994.7136  51.6% 80510  240s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 13
#   Clique: 5
#   Zero half: 15
#   RLT: 6
#   Lazy constraints: 7
#
# Explored 5 nodes (409083 simplex iterations) in 240.04 seconds (863.62 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 2: 115809 118340
#
# Time limit reached
# Best objective 1.158087300000e+05, best bound 5.599471364502e+04, gap 51.6490%
#
# User-callback calls 50365, time in user-callback 0.07 sec
# Model solved with status 9.
# Model solved with status 9.
# Saved configuration result for instance: 9R-alpha=021_Flow_60perc_HubCosts_20perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=True, use_ML_transhipment=False
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 26814 rows, 49276 columns and 170976 nonzeros
# Model fingerprint: 0x20de4594
# Variable types: 0 continuous, 49276 integer (49276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2612 rows and 696 columns
# Presolve time: 0.13s
# Presolved: 24202 rows, 48580 columns, 134956 nonzeros
# Variable types: 0 continuous, 48580 integer (48580 binary)
# Root relaxation presolved: 24202 rows, 48580 columns, 134956 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.481601e+04, 12528 iterations, 1.13 seconds (2.60 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 54816.0073    0 2533          - 54816.0073      -     -    2s
#      0     0 56020.0612    0  525          - 56020.0612      -     -   10s
# H    0     0                    92933.440000 56020.0612  39.7%     -   10s
#      0     0 56020.6218    0  658 92933.4400 56020.6218  39.7%     -   11s
#      0     0 56020.6218    0  662 92933.4400 56020.6218  39.7%     -   11s
#      0     0 56020.6218    0 1023 92933.4400 56020.6218  39.7%     -   12s
#      0     0 56020.6218    0 1083 92933.4400 56020.6218  39.7%     -   13s
#      0     0 56020.6218    0  759 92933.4400 56020.6218  39.7%     -   14s
#      0     0 56020.6218    0  760 92933.4400 56020.6218  39.7%     -   14s
#      0     0 56020.6218    0  787 92933.4400 56020.6218  39.7%     -   15s
#      0     0 56020.6218    0  973 92933.4400 56020.6218  39.7%     -   16s
#      0     0 56020.6218    0  983 92933.4400 56020.6218  39.7%     -   17s
#      0     0 56020.6218    0  983 92933.4400 56020.6218  39.7%     -   17s
#      0     2 56020.6218    0  983 92933.4400 56020.6218  39.7%     -   23s
#      1     4 56154.7856    1 1956 92933.4400 56020.6218  39.7% 267141  127s
#      3     8 56154.7856    2 1955 92933.4400 56020.6347  39.7% 89643  177s
#      7    16 56154.7856    3 1230 92933.4400 56154.7856  39.6% 65316  191s
#     15    30 56154.7856    4 1130 92933.4400 56154.7856  39.6% 36368  217s
#     29    42 infeasible    5      92933.4400 56162.9815  39.6% 34350  221s
# H   42    42                    91807.630000 56162.9815  38.8% 24846  221s
#     57    68 71634.7891    6  663 91807.6300 56165.2255  38.8% 19078  225s
#     71    86 72504.1452    6  661 91807.6300 56165.2255  38.8% 15619  230s
#    135   149 73571.3540   10  660 91807.6300 56165.2255  38.8%  9984  237s
# H  139   149                    90681.820000 56165.2255  38.1%  9725  237s
#    186   180 74046.1591   15  605 90681.8200 56165.2255  38.1%  8027  240s
#
# Cutting planes:
#   Gomory: 3
#   Lift-and-project: 2
#   Zero half: 13
#
# Explored 187 nodes (1542544 simplex iterations) in 240.03 seconds (965.09 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 3: 90681.8 91807.6 92933.4
#
# Time limit reached
# Best objective 9.068182000000e+04, best bound 5.616522552990e+04, gap 38.0634%
#
# User-callback calls 90511, time in user-callback 0.19 sec
# Model solved with status 9.
# Model solved with status 9.
# Saved configuration result for instance: 9R-alpha=021_Flow_60perc_HubCosts_20perc
# Configuration: use_ml_guidance=True, use_location_first=False, use_ML_direct=False, use_ML_transhipment=True
# Skipping location decisions... Using all hubs as candidates.
# Solving routing decisions...
# Set parameter TimeLimit to value 240
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 19950 rows, 49276 columns and 90984 nonzeros
# Model fingerprint: 0x54360045
# Variable types: 0 continuous, 49276 integer (49276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 708 rows and 696 columns
# Presolve time: 0.09s
# Presolved: 19242 rows, 48580 columns, 87852 nonzeros
# Variable types: 0 continuous, 48580 integer (48580 binary)
#
# Root relaxation: objective 5.367940e+04, 15034 iterations, 1.07 seconds (2.84 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 53679.3978    0  620          - 53679.3978      -     -    2s
#      0     0 62251.5115    0  689          - 62251.5115      -     -    4s
#      0     0 62251.5115    0  510          - 62251.5115      -     -    4s
#      0     0 63943.7893    0  925          - 63943.7893      -     -    5s
#      0     0 63943.7893    0  901          - 63943.7893      -     -    5s
#      0     0 63943.7893    0 1095          - 63943.7893      -     -    5s
# H    0     0                    93060.160000 63943.7893  31.3%     -    6s
#      0     0 63943.7893    0  690 93060.1600 63943.7893  31.3%     -    7s
#      0     0 63943.7893    0  577 93060.1600 63943.7893  31.3%     -    8s
#      0     0 63943.7893    0  803 93060.1600 63943.7893  31.3%     -    8s
#      0     0 63943.7893    0  715 93060.1600 63943.7893  31.3%     -    9s
#      0     0 63943.7893    0  714 93060.1600 63943.7893  31.3%     -    9s
#      0     0 63943.7893    0  589 93060.1600 63943.7893  31.3%     -    9s
#      0     0 63943.7893    0  589 93060.1600 63943.7893  31.3%     -   10s
# H    0     0                    89597.500000 63943.7893  28.6%     -   11s
#      0     2 63943.7893    0  589 89597.5000 63943.7893  28.6%     -   11s
# *   74    76               8    85460.740000 63963.9194  25.2%  1067   13s
#    253   214 75361.1050   17  187 85460.7400 63963.9194  25.2%   664   15s
#    710   401 69710.0163    7  258 85460.7400 69622.0999  18.5%   460   20s
#   2287  1163 75110.7175   14  204 85460.7400 69895.0150  18.2%   404   25s

#
# Cutting planes:
#   Gomory: 8
#   Cover: 8
#   MIR: 4
#   Flow cover: 7
#   Inf proof: 4
#   Zero half: 10
#   RLT: 8
#   Lazy constraints: 204
#
# Explored 39868 nodes (18512891 simplex iterations) in 240.06 seconds (785.22 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 4: 85460.7 85460.7 89597.5 93060.2
#
# Time limit reached
# Best objective 8.546073694457e+04, best bound 7.153872118383e+04, gap 16.2905%
#
# User-callback calls 133362, time in user-callback 0.47 sec
# Model solved with status 9.
# Model solved with status 9.
# Saved configuration result for instance: 9R-alpha=021_Flow_60perc_HubCosts_20perc
# All results saved to ML Experiments/Heuristic Results/Heuristic_output_ML_combined_output_features_1.csv

# %%
# def main(data_folders, ml_input_file, heuristic_output_folder):
#     # Load the ML combined input file
#     try:
#         ml_combined_data = pd.read_csv(ml_input_file)
#     except FileNotFoundError:
#         print(f"Error: File '{ml_input_file}' not found. Please check the path.")
#         return

#     # Extract unique instance IDs
#     unique_instance_ids = ml_combined_data["Instance ID"].unique()

#     # Create heuristic output folder if it doesn't exist
#     os.makedirs(heuristic_output_folder, exist_ok=True)

#     # Dynamically create the output file name based on the input file
#     input_csv_name = os.path.basename(ml_input_file)
#     output_csv_name = f"Heuristic_output_{input_csv_name}"
#     output_file = os.path.join(heuristic_output_folder, output_csv_name)

#     # Define CSV column structure
#     columns = [
#         "Instance ID", "use_ml_guidance", "use_location_first", "use_ML_direct", "use_ML_transhipment",
#         "ML_Optimization status", "ML_Optimality Gap", "ML_OFV - Total Costs", "ML_Total Solving Time",
#         "Stage 1 Feasibility", "Stage 2 Feasibility"
#     ]

#     # Create the output file if it doesn’t exist
#     if not os.path.exists(output_file):
#         pd.DataFrame(columns=columns).to_csv(output_file, index=False)

#     # Define all configurations for solving
#     configurations = [
#         # (False, False, False, False),# No ML guidance, no location first
#         (False, True, False, False),# No ML guidance, location first
#         # (True, False, True, True),  # ML-guided (both, no location first)
#         # (True, False, True, False), # ML-guided (direct only, no location first)
#         # (True, False, False, True), # ML-guided (transshipment only, no location first)
#         # (True, True, True, False),   # ML-guided (direct only, location first)
#         # (True, True, False, True),  # ML-guided (transshipment only, location first)
#         # (True, True, True, True),   # ML-guided (both, location first)
#     ]

#     # Loop through each instance
#     for instance_id in unique_instance_ids:
#         # Search for the instance file in the data folders
#         instance_file = None
#         for folder in data_folders:
#             potential_path = os.path.join(folder, f"{instance_id}.dat")
#             if os.path.isfile(potential_path):
#                 instance_file = potential_path
#                 break

#         if instance_file is None:
#             print(f"Instance file '{instance_id}.dat' not found in any data folder.")
#             continue

#         print(f"Processing instance: {instance_id}")

#         # Load instance data
#         instance_data = read_instance_from_dat(instance_file)

#         # Filter ML data for the current instance
#         ml_data = ml_combined_data[ml_combined_data["Instance ID"] == instance_id]

#         # Loop through each configuration
#         for use_ml_guidance, use_location_first, use_ML_direct, use_ML_transhipment in configurations:
#             # Ensure at least one of use_ML_direct or use_ML_transhipment is True if use_ml_guidance is True
#             if use_ml_guidance and not (use_ML_direct or use_ML_transhipment):
#                 print("Skipping invalid configuration.")
#                 continue

#             print(f"Configuration: use_ml_guidance={use_ml_guidance}, use_location_first={use_location_first}, "
#                   f"use_ML_direct={use_ML_direct}, use_ML_transhipment={use_ML_transhipment}")

#             fixed_hubs = []  # Default value if not solving location decisions
#             stage1_status = "Not Solved"
#             stage2_status = "Not Solved"
#             optimization_status = None
#             optimality_gap = None
#             objective_value = None
#             solving_time = None

#             # Stage 1: Solve flow-aware location decisions
#             if use_location_first:
#                 try:
#                     print("Solving location decisions...")
#                     fixed_hubs,cou = solve_flow_aware_location_decisions(instance_data, ml_data, use_ml_guidance,use_ML_direct, use_ML_transhipment)
#                     stage1_status = "Feasible"
#                 except Exception as e:
#                     print(f"Stage 1 Infeasible: {e}")
#                     stage1_status = "Infeasible"
#                     fixed_hubs = []
#             else:
#                 print("Skipping location decisions... Using all hubs as candidates.")
#                 fixed_hubs = list(range(1, int(instance_data.S) + 1))  # Use all hubs as candidates
#                 stage1_status = "Skipped"

#             # Stage 2: Solve routing decisions
#             try:
#                 print("Solving routing decisions...")
#                 result = solve_all_or_routing_decisions(
#                     instance_data, ml_data, fixed_hubs, use_ml_guidance, use_location_first, use_ML_direct, use_ML_transhipment
#                 )

#                 if result['status'] in [GRB.OPTIMAL, GRB.TIME_LIMIT]:
#                     stage2_status = "Feasible"
#                     optimization_status = "Optimal" if result['status'] == GRB.OPTIMAL else "Time Limit"
#                     optimality_gap = result.get("optimality_gap", None)
#                     objective_value = result.get("objective_value", None)
#                     solving_time = result.get("total_solving_time", None)

#                 else:
#                     stage2_status = "Infeasible"
#                     optimization_status = "Infeasible"

#             except Exception as e:
#                 print(f"Error in Stage 2: {e}")
#                 stage2_status = "Error"
#                 optimization_status = "Error"

#             # Create a row of results
#             result_row = {
#                 "Instance ID": instance_id,
#                 "use_ml_guidance": use_ml_guidance,
#                 "use_location_first": use_location_first,
#                 "use_ML_direct": use_ML_direct,
#                 "use_ML_transhipment": use_ML_transhipment,
#                 "ML_Optimization status": optimization_status,
#                 "ML_Optimality Gap": optimality_gap,
#                 "ML_OFV - Total Costs": objective_value,
#                 "ML_Total Solving Time": solving_time,
#                 "Stage 1 Feasibility": stage1_status,
#                 "Stage 2 Feasibility": stage2_status
#             }

#             # Append to the CSV
#             pd.DataFrame([result_row]).to_csv(output_file, mode='a', header=False, index=False)

#             print(f"Saved configuration result for instance: {instance_id}")

#     print(f"All results saved to {output_file}")

# %%
# if __name__ == "__main__":
#     # Define data folders to search for instance files
#     data_folders = [
#         "DATA/Luisa Data",
#         "DATA/Modified/Flow Modifications",
#         "DATA/Modified/Hub Cost Modifications",
#         "DATA/Modified/BOTH",
#     ]

#     # Path to the ML combined output file
#     ml_input_file = "ML Experiments/XG_BOOST Predictions/ML_combined_output_features_1.csv"

#     # Path to the heuristic output folder
#     heuristic_output_folder = "ML Experiments/Heuristic Results"

#     # Run the main function
#     main(data_folders, ml_input_file, heuristic_output_folder)
# Out:
# Processing instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-20
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 281 rows, 585 columns and 760 nonzeros
# Model fingerprint: 0x95201bd2
# Variable types: 0 continuous, 585 integer (585 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 2278.3994000
# Presolve removed 0 rows and 329 columns
# Presolve time: 0.00s
# Presolved: 281 rows, 256 columns, 760 nonzeros
# Variable types: 0 continuous, 256 integer (256 binary)
# Found heuristic solution: objective 1340.8952000
#
# Root relaxation: objective 1.215394e+03, 75 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1215.39400    0   70 1340.89520 1215.39400  9.36%     -    0s
# H    0     0                    1310.9245000 1215.39400  7.29%     -    0s
#      0     0 1217.51775    0   60 1310.92450 1217.51775  7.13%     -    0s
# H    0     0                    1256.6739000 1217.51775  3.12%     -    0s
#      0     0 1220.07575    0   46 1256.67390 1220.07575  2.91%     -    0s
#      0     0 1220.07575    0   66 1256.67390 1220.07575  2.91%     -    0s
# H    0     0                    1230.2923000 1220.07575  0.83%     -    0s
# H    0     0                    1221.2044000 1220.07575  0.09%     -    0s
#      0     0     cutoff    0      1221.20440 1221.20440  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Zero half: 18
#
# Explored 1 nodes (230 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 6: 1221.2 1230.29 1256.67 ... 2278.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.221204400000e+03, best bound 1.221204400000e+03, gap 0.0000%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 12246 rows, 31659 columns and 67212 nonzeros
# Model fingerprint: 0x4ba5dfb4
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 128 rows and 116 columns
# Presolve time: 0.05s
# Presolved: 12118 rows, 31543 columns, 65860 nonzeros
# Variable types: 0 continuous, 31543 integer (31543 binary)
#
# Root relaxation: objective 3.307391e+04, 16015 iterations, 1.62 seconds (3.98 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33073.9129    0  337          - 33073.9129      -     -    2s
# H    0     0                    53604.040000 33073.9129  38.3%     -    2s
#      0     0 48109.6826    0  685 53604.0400 48109.6826  10.2%     -    6s
#      0     0 48109.6826    0  965 53604.0400 48109.6826  10.2%     -    7s
#      0     0 48109.6826    0  656 53604.0400 48109.6826  10.2%     -    8s
# H    0     0                    52752.370000 48109.6826  8.80%     -    8s
# H    0     0                    52745.830000 48109.6826  8.79%     -    8s
#      0     0 48109.8873    0  642 52745.8300 48109.8873  8.79%     -    8s
#      0     0 48129.8679    0  752 52745.8300 48129.8679  8.75%     -   10s
# H    0     0                    50230.510000 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  627 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     2 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   12s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 13
#   Clique: 13
#   MIR: 2
#   StrongCG: 1
#   GUB cover: 9
#   Zero half: 4
#   RLT: 17
#   Lazy constraints: 1
#
# Explored 3 nodes (62068 simplex iterations) in 13.24 seconds (33.59 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 4: 50230.5 52745.8 52752.4 53604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.023051000000e+04, best bound 5.023048134328e+04, gap 0.0001%
#
# User-callback calls 2087, time in user-callback 0.01 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 4)
#   Arc (1, 5)
#   Arc (2, 6)
#   Arc (4, 2)
#   Arc (5, 0)
#   Arc (6, 8)
#   Arc (8, 1)
# Vehicle 1:
# Vehicle 2:
#   Arc (0, 5)
#   Arc (2, 4)
#   Arc (3, 7)
#   Arc (4, 0)
#   Arc (5, 3)
#   Arc (7, 2)
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_5perc
# Processing instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 263 rows, 585 columns and 712 nonzeros
# Model fingerprint: 0x6fb0092c
# Variable types: 0 continuous, 585 integer (585 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 0 rows and 345 columns
# Presolve time: 0.00s
# Presolved: 263 rows, 240 columns, 712 nonzeros
# Variable types: 0 continuous, 240 integer (240 binary)
# Found heuristic solution: objective 4616.6127000
#
# Root relaxation: objective 4.509154e+03, 105 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4509.15360    0   66 4616.61270 4509.15360  2.33%     -    0s
# H    0     0                    4521.0163000 4509.15360  0.26%     -    0s
# H    0     0                    4515.7756000 4509.15360  0.15%     -    0s
#      0     0 4510.40160    0   58 4515.77560 4510.40160  0.12%     -    0s
#      0     0 4510.40160    0   37 4515.77560 4510.40160  0.12%     -    0s
# H    0     0                    4512.2194000 4510.40160  0.04%     -    0s
#      0     0 4511.48400    0   34 4512.21940 4511.48400  0.02%     -    0s
#      0     0          -    0      4512.21940 4512.15150  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 11
#   RLT: 1
#
# Explored 1 nodes (201 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 5: 4512.22 4515.78 4515.78 ... 4616.61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.512219400000e+03, best bound 4.512151500000e+03, gap 0.0015%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 11486 rows, 31659 columns and 62996 nonzeros
# Model fingerprint: 0x8283ec9a
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 600 rows and 340 columns
# Presolve time: 0.06s
# Presolved: 10886 rows, 31319 columns, 65860 nonzeros
# Variable types: 0 continuous, 31319 integer (31319 binary)
#
# Root relaxation: objective 5.407722e+04, 8859 iterations, 0.57 seconds (1.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0

#
# Cutting planes:
#   Gomory: 5
#   Cover: 6
#   Zero half: 2
#   Lazy constraints: 7
#
# Explored 33033 nodes (10899729 simplex iterations) in 139.43 seconds (420.85 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 74181.3 74181.3 74589.2 ... 109874
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (6.4324e-06) exceeds tolerance
# Best objective 7.418132427938e+04, best bound 7.418132427938e+04, gap 0.0000%
#
# User-callback calls 93722, time in user-callback 0.18 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 6)
#   Arc (1, 7)
#   Arc (5, 1)
#   Arc (6, 5)
#   Arc (7, 0)
# Vehicle 1:
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
#   Arc (0, 5)
#   Arc (1, 8)
#   Arc (2, 1)
#   Arc (3, 7)
#   Arc (4, 2)
#   Arc (5, 3)
#   Arc (6, 0)
#   Arc (7, 4)
#   Arc (8, 6)
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 8R-alpha=021_Flow_60perc_HubCosts_5perc
# Processing instance: 8R-alpha=021_Flow_50perc_HubCosts_20perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 281 rows, 585 columns and 760 nonzeros
# Model fingerprint: 0x95201bd2
# Variable types: 0 continuous, 585 integer (585 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 2278.3994000
# Presolve removed 0 rows and 329 columns
# Presolve time: 0.00s
# Presolved: 281 rows, 256 columns, 760 nonzeros
# Variable types: 0 continuous, 256 integer (256 binary)
# Found heuristic solution: objective 1340.8952000
#
# Root relaxation: objective 1.215394e+03, 75 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1215.39400    0   70 1340.89520 1215.39400  9.36%     -    0s
# H    0     0                    1310.9245000 1215.39400  7.29%     -    0s
#      0     0 1217.51775    0   60 1310.92450 1217.51775  7.13%     -    0s
# H    0     0                    1256.6739000 1217.51775  3.12%     -    0s
#      0     0 1220.07575    0   46 1256.67390 1220.07575  2.91%     -    0s
#      0     0 1220.07575    0   66 1256.67390 1220.07575  2.91%     -    0s
# H    0     0                    1230.2923000 1220.07575  0.83%     -    0s
# H    0     0                    1221.2044000 1220.07575  0.09%     -    0s
#      0     0     cutoff    0      1221.20440 1221.20440  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Zero half: 18
#
# Explored 1 nodes (230 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 6: 1221.2 1230.29 1256.67 ... 2278.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.221204400000e+03, best bound 1.221204400000e+03, gap 0.0000%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 12246 rows, 31659 columns and 67212 nonzeros
# Model fingerprint: 0x4ba5dfb4
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 128 rows and 116 columns
# Presolve time: 0.06s
# Presolved: 12118 rows, 31543 columns, 65860 nonzeros
# Variable types: 0 continuous, 31543 integer (31543 binary)
#
# Root relaxation: objective 3.307391e+04, 16015 iterations, 1.54 seconds (3.98 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 33073.9129    0  337          - 33073.9129      -     -    2s
# H    0     0                    53604.040000 33073.9129  38.3%     -    2s
#      0     0 48109.6826    0  685 53604.0400 48109.6826  10.2%     -    6s
#      0     0 48109.6826    0  965 53604.0400 48109.6826  10.2%     -    7s
#      0     0 48109.6826    0  656 53604.0400 48109.6826  10.2%     -    8s
# H    0     0                    52752.370000 48109.6826  8.80%     -    8s
# H    0     0                    52745.830000 48109.6826  8.79%     -    8s
#      0     0 48109.8873    0  642 52745.8300 48109.8873  8.79%     -    8s
#      0     0 48129.8679    0  752 52745.8300 48129.8679  8.75%     -   10s
# H    0     0                    50230.510000 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  627 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     0 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   10s
#      0     2 48129.8679    0  666 50230.5100 48129.8679  4.18%     -   12s
#
# Cutting planes:
#   Gomory: 2
#   Cover: 13
#   Clique: 13
#   MIR: 2
#   StrongCG: 1
#   GUB cover: 9
#   Zero half: 4
#   RLT: 17
#   Lazy constraints: 1
#
# Explored 3 nodes (62068 simplex iterations) in 13.20 seconds (33.59 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 4: 50230.5 52745.8 52752.4 53604
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.023051000000e+04, best bound 5.023048134328e+04, gap 0.0001%
#
# User-callback calls 2228, time in user-callback 0.01 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 4)
#   Arc (1, 5)
#   Arc (2, 6)
#   Arc (4, 2)
#   Arc (5, 0)
#   Arc (6, 8)
#   Arc (8, 1)
# Vehicle 1:
# Vehicle 2:
#   Arc (0, 5)
#   Arc (2, 4)
#   Arc (3, 7)
#   Arc (4, 0)
#   Arc (5, 3)
#   Arc (7, 2)
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 8R-alpha=021_Flow_50perc_HubCosts_20perc
# Processing instance: 8R-alpha=021_Flow_60perc_HubCosts_20perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 263 rows, 585 columns and 712 nonzeros
# Model fingerprint: 0x6fb0092c
# Variable types: 0 continuous, 585 integer (585 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 4e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Presolve removed 0 rows and 345 columns
# Presolve time: 0.00s
# Presolved: 263 rows, 240 columns, 712 nonzeros
# Variable types: 0 continuous, 240 integer (240 binary)
# Found heuristic solution: objective 4616.6127000
#
# Root relaxation: objective 4.509154e+03, 105 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4509.15360    0   66 4616.61270 4509.15360  2.33%     -    0s
# H    0     0                    4521.0163000 4509.15360  0.26%     -    0s
# H    0     0                    4515.7756000 4509.15360  0.15%     -    0s
#      0     0 4510.40160    0   58 4515.77560 4510.40160  0.12%     -    0s
#      0     0 4510.40160    0   37 4515.77560 4510.40160  0.12%     -    0s
# H    0     0                    4512.2194000 4510.40160  0.04%     -    0s
#      0     0 4511.48400    0   34 4512.21940 4511.48400  0.02%     -    0s
#      0     0          -    0      4512.21940 4512.15150  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 11
#   RLT: 1
#
# Explored 1 nodes (201 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 5: 4512.22 4515.78 4515.78 ... 4616.61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.512219400000e+03, best bound 4.512151500000e+03, gap 0.0015%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 11486 rows, 31659 columns and 62996 nonzeros
# Model fingerprint: 0x8283ec9a
# Variable types: 0 continuous, 31659 integer (31659 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 600 rows and 340 columns
# Presolve time: 0.06s
# Presolved: 10886 rows, 31319 columns, 65860 nonzeros
# Variable types: 0 continuous, 31319 integer (31319 binary)
#
# Root relaxation: objective 5.407722e+04, 8859 iterations, 0.57 seconds (1.28 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 54077.2197    0  400          - 54077.2197      -     -    1s
#      0     0 60042.9206    0  735          - 60042.9206      -     -    2s
#      0     0 60042.9206    0  858          - 60042.9206      -     -    3s
#      0     0 60042.9206    0  652          - 60042.9206      -     -    4s
#      0     0 60042.9206    0  539          - 60042.9206      -     -    5s
#      0     0 60042.9206    0  708          - 60042.9206      -     -    5s
#      0     0 60042.9206    0  543          - 60042.9206      -     -    5s
#      0     0 60042.9206    0  672          - 60042.9206      -     -    5s
#      0     0 60042.9206    0  707          - 60042.9206      -     -    6s
#      0     0 60042.9206    0  523          - 60042.9206      -     -    6s
# H    0     0                    109874.44500 60042.9206  45.4%     -    6s
#      0     2 60042.9206    0  429 109874.445 60042.9206  45.4%     -    7s
# H   30    39                    88831.105000 60053.0408  32.4%  2393    9s
#     71    77 60148.0991    8  384 88831.1050 60055.7532  32.4%  1317   10s
# H   72    77                    85345.720000 60055.7532  29.6%  1299   10s
# H   80    77                    85258.600000 60055.7532  29.6%  1278   10s
# *  270   203              13    79803.985000 60055.7532  24.7%   827   12s
# *  282   203              10    78913.450000 60055.7532  23.9%   827   12s
# *  309   204              15    78557.200000 60109.9595  23.5%   845   12s
#    407   274 70989.4293   12  186 78557.2000 60109.9595  23.5%   800   15s
# *  649   388              16    74589.160000 60109.9595  19.4%   688   18s
# H  752   422                    74181.325000 60135.9418  18.9%   642   19s
#    866   467 72681.0925   12  108 74181.3250 60135.9418  18.9%   613   25s
# * 1806   701              19    74181.324279 60711.1416  18.2%   450   27s
#   2890   834 71999.5625   14  203 74181.3243 60787.1965  18.1%   378   30s
#   5913  1093     cutoff    8      74181.3243 71365.6978  3.80%   304   35s
#   8298  1284 73089.7900   12  409 74181.3243 71637.8673  3.43%   275   41s
#   8304  1288 72023.3531   14  396 74181.3243 71637.8673  3.43%   275   46s
#   8375  1348 71637.8673   20  355 74181.3243 71637.8673  3.43%   290   50s
#   8620  1400 73046.9575   27  172 74181.3243 71637.8673  3.43%   303   59s
#   8639  1396 73406.9706   28  141 74181.3243 71637.8673  3.43%   303   60s
#   9276  1408     cutoff   28      74181.3243 71637.8673  3.43%   318   66s
#   9757  1405     cutoff   28      74181.3243 71637.8673  3.43%   327   70s
#  10853  1332 71845.2925   29  150 74181.3243 71637.8673  3.43%   332   75s
#  11905  1210 72328.2925   25  112 74181.3243 71637.8673  3.43%   339   80s
#  13647  1441     cutoff   38      74181.3243 71637.8673  3.43%   347   85s
#  14925  1606 72450.8950   29  136 74181.3243 71637.8673  3.43%   347   91s
#  16045  1747 72413.1625   40  178 74181.3243 71637.8673  3.43%   345   95s
#  17831  1890 73425.6475   28   87 74181.3243 71746.4272  3.28%   346  102s
#  18429  1949     cutoff   29      74181.3243 71787.6240  3.23%   347  105s
#  20176  1934     cutoff   27      74181.3243 71894.5054  3.08%   348  110s
#  22074  1884 72221.0763   27  251 74181.3243 72042.2950  2.88%   349  115s
#  24651  1685 73817.2900   27  107 74181.3243 72262.1352  2.59%   347  121s
#  26676  1460     cutoff   30      74181.3243 72442.7794  2.34%   345  125s
#  29055   938     cutoff   25      74181.3243 72661.0969  2.05%   341  130s
#  30441   522     cutoff   34      74181.3243 72818.9775  1.84%   338  136s
#
# Cutting planes:
#   Gomory: 5
#   Cover: 6
#   Zero half: 2
#   Lazy constraints: 7
#
# Explored 33033 nodes (10899729 simplex iterations) in 138.70 seconds (420.85 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 74181.3 74181.3 74589.2 ... 109874
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (6.4324e-06) exceeds tolerance
# Best objective 7.418132427938e+04, best bound 7.418132427938e+04, gap 0.0000%
#
# User-callback calls 93829, time in user-callback 0.19 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 6)
#   Arc (1, 7)
#   Arc (5, 1)
#   Arc (6, 5)
#   Arc (7, 0)
# Vehicle 1:
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
#   Arc (0, 5)
#   Arc (1, 8)
#   Arc (2, 1)
#   Arc (3, 7)
#   Arc (4, 2)
#   Arc (5, 3)
#   Arc (6, 0)
#   Arc (7, 4)
#   Arc (8, 6)
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 8R-alpha=021_Flow_60perc_HubCosts_20perc
# Processing instance: 9R-alpha=021_Flow_50perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 362 rows, 820 columns and 990 nonzeros
# Model fingerprint: 0x01ac68ce
# Variable types: 0 continuous, 820 integer (820 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 2510.3936000
# Presolve removed 0 rows and 487 columns
# Presolve time: 0.00s
# Presolved: 362 rows, 333 columns, 990 nonzeros
# Variable types: 0 continuous, 333 integer (333 binary)
# Found heuristic solution: objective 1816.5016000
#
# Root relaxation: objective 1.751880e+03, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
#   1375   696     cutoff   13      51672.6700 51034.8148  1.23%   917  185s
#   1795   819     cutoff   12      51672.6700 51063.0108  1.18%   817  190s
#   2321   985 51333.2502   23  309 51672.6700 51068.7722  1.17%   748  195s
#   3153  1112     cutoff   19      51672.6700 51099.4098  1.11%   676  219s
#   3192  1085     cutoff   27      51672.6700 51107.1743  1.09%   680  221s
#   3797  1091     cutoff   18      51672.6700 51131.1559  1.05%   648  225s
#   4823  1093     cutoff   35      51672.6700 51179.6477  0.95%   600  230s
#   6025   931     cutoff   13      51672.6700 51249.9153  0.82%   543  235s
#   8224     0     cutoff   59      51672.6700 51468.4939  0.40%   459  240s
#
# Cutting planes:
#   Cover: 19
#   Clique: 8
#   MIR: 11
#   Zero half: 17
#   RLT: 2
#   Lazy constraints: 1
#
# Explored 8344 nodes (3959202 simplex iterations) in 240.44 seconds (666.18 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 4: 51672.7 52344.2 52941.3 53742.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.167267000000e+04, best bound 5.167267000000e+04, gap 0.0000%
#
# User-callback calls 110296, time in user-callback 0.20 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 4)
#   Arc (1, 0)
#   Arc (3, 5)
#   Arc (4, 7)
#   Arc (5, 1)
#   Arc (7, 3)
# Vehicle 1:
#   Arc (0, 1)
#   Arc (1, 8)
#   Arc (2, 9)
#   Arc (3, 7)
#   Arc (4, 0)
#   Arc (5, 3)
#   Arc (6, 5)
#   Arc (7, 2)
#   Arc (8, 6)
#   Arc (9, 4)
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 9R-alpha=021_Flow_50perc_HubCosts_5perc
# Processing instance: 9R-alpha=021_Flow_60perc_HubCosts_5perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 442 rows, 820 columns and 1206 nonzeros
# Model fingerprint: 0xf911b8ef
# Variable types: 0 continuous, 820 integer (820 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 9672.7256000
# Presolve removed 0 rows and 415 columns
# Presolve time: 0.00s
# Presolved: 442 rows, 405 columns, 1206 nonzeros
# Variable types: 0 continuous, 405 integer (405 binary)
# Found heuristic solution: objective 6272.4339000
#
# Root relaxation: objective 5.433533e+03, 90 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5433.53300    0   78 6272.43390 5433.53300  13.4%     -    0s
# H    0     0                    5575.2169000 5433.53300  2.54%     -    0s
# H    0     0                    5462.8405000 5433.53300  0.54%     -    0s
#      0     0 5433.64835    0   86 5462.84050 5433.64835  0.53%     -    0s
#      0     0 5433.64835    0   76 5462.84050 5433.64835  0.53%     -    0s
# H    0     0                    5455.8211000 5433.64835  0.41%     -    0s
# H    0     0                    5449.1405000 5433.64835  0.28%     -    0s
#      0     0 5434.16195    0   82 5449.14050 5434.16195  0.27%     -    0s
# H    0     0                    5447.4861000 5434.16225  0.24%     -    0s
# H    0     0                    5443.5956000 5434.16225  0.17%     -    0s
#      0     0 5434.16225    0   82 5443.59560 5434.16225  0.17%     -    0s
# H    0     0                    5438.8003000 5434.16225  0.09%     -    0s
#      0     0 5436.28120    0   99 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.28120    0   54 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.28120    0   62 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.46293    0   75 5438.80030 5436.46293  0.04%     -    0s
#      0     0          -    0      5438.80030 5438.33090  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 4
#   Zero half: 30
#   RLT: 4
#
# Explored 1 nodes (478 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 5438.8 5438.8 5443.6 ... 6272.43
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.438800300000e+03, best bound 5.438330900000e+03, gap 0.0086%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 21807 rows, 49276 columns and 122409 nonzeros
# Model fingerprint: 0x33394527
# Variable types: 0 continuous, 49276 integer (49276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 773 rows and 705 columns
# Presolve time: 0.10s
# Presolved: 21034 rows, 48571 columns, 116524 nonzeros
# Variable types: 0 continuous, 48571 integer (48571 binary)
# Root relaxation presolved: 21034 rows, 48571 columns, 116524 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.371068e+04, 6986 iterations, 0.28 seconds (0.53 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 53710.6836    0  429          - 53710.6836      -     -    1s
# H    0     0                    88248.220000 53710.6836  39.1%     -    1s
#      0     0 69091.1163    0  457 88248.2200 69091.1163  21.7%     -    3s
# H    0     0                    85460.740000 69091.1163  19.2%     -    3s
#      0     0 69091.1163    0  734 85460.7400 69091.1163  19.2%     -    4s
#      0     0 69091.1163    0  734 85460.7400 69091.1163  19.2%     -    4s
#      0     0 69326.2598    0  544 85460.7400 69326.2598  18.9%     -    5s
#      0     0 69326.2598    0 1037 85460.7400 69326.2598  18.9%     -    6s
#      0     0 69326.2598    0 1018 85460.7400 69326.2598  18.9%     -    6s
#      0     0 69326.2598    0  689 85460.7400 69326.2598  18.9%     -    8s
#      0     0 69326.2598    0  703 85460.7400 69326.2598  18.9%     -    8s
#      0     0 69326.2598    0  597 85460.7400 69326.2598  18.9%     -    8s
#      0     0 69326.2598    0  697 85460.7400 69326.2598  18.9%     -    9s
#      0     0 69326.2598    0  695 85460.7400 69326.2598  18.9%     -    9s
#      0     0 69326.2598    0  633 85460.7400 69326.2598  18.9%     -   10s
#      0     0 69326.2598    0  633 85460.7400 69326.2598  18.9%     -   10s
#      0     2 69326.2598    0  588 85460.7400 69326.2598  18.9%     -   11s
#     15    26 70133.4612    4  626 85460.7400 69326.2598  18.9%  2154   15s
#    173   169 75265.0675   13  216 85460.7400 69326.2598  18.9%  1059   20s
#    300   265 71303.4975    8  369 85460.7400 69752.2075  18.4%   926   28s
#    371   303 72689.1325   11  133 85460.7400 69752.2075  18.4%   886   30s
#    628   477 71002.8605   10  416 85460.7400 69752.2075  18.4%   941   35s
#  92714 21397     cutoff   35      85460.7400 73305.9495  14.2%   823 1624s
#  94547 21591 80579.7450   41  376 85460.7400 73323.9901  14.2%   822 1645s
#  95846 21788 76848.8392   35  440 85460.7400 73349.7310  14.2%   823 1667s
# ...
# Best objective 5.167267000000e+04, best bound 5.167267000000e+04, gap 0.0000%
#
# User-callback calls 103617, time in user-callback 0.20 sec
# Model solved with status 2.
# Optimal solution found.
# Vehicle 0:
#   Arc (0, 4)
#   Arc (1, 0)
#   Arc (3, 5)
#   Arc (4, 7)
#   Arc (5, 1)
#   Arc (7, 3)
# Vehicle 1:
#   Arc (0, 1)
#   Arc (1, 8)
#   Arc (2, 9)
#   Arc (3, 7)
#   Arc (4, 0)
#   Arc (5, 3)
#   Arc (6, 5)
#   Arc (7, 2)
#   Arc (8, 6)
#   Arc (9, 4)
# Vehicle 2:
# Vehicle 3:
# Vehicle 4:
# Vehicle 5:
# Optimal solution found.
# Model solved with status 2.
# Discarded solution information
# Saved configuration result for instance: 9R-alpha=021_Flow_50perc_HubCosts_20perc
# Processing instance: 9R-alpha=021_Flow_60perc_HubCosts_20perc
# Configuration: use_ml_guidance=False, use_location_first=True, use_ML_direct=False, use_ML_transhipment=False
# Solving location decisions...
# Set parameter TimeLimit to value 120
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 442 rows, 820 columns and 1206 nonzeros
# Model fingerprint: 0xf911b8ef
# Variable types: 0 continuous, 820 integer (820 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e+00, 3e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 9672.7256000
# Presolve removed 0 rows and 415 columns
# Presolve time: 0.00s
# Presolved: 442 rows, 405 columns, 1206 nonzeros
# Variable types: 0 continuous, 405 integer (405 binary)
# Found heuristic solution: objective 6272.4339000
#
# Root relaxation: objective 5.433533e+03, 90 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5433.53300    0   78 6272.43390 5433.53300  13.4%     -    0s
# H    0     0                    5575.2169000 5433.53300  2.54%     -    0s
# H    0     0                    5462.8405000 5433.53300  0.54%     -    0s
#      0     0 5433.64835    0   86 5462.84050 5433.64835  0.53%     -    0s
#      0     0 5433.64835    0   76 5462.84050 5433.64835  0.53%     -    0s
# H    0     0                    5455.8211000 5433.64835  0.41%     -    0s
# H    0     0                    5449.1405000 5433.64835  0.28%     -    0s
#      0     0 5434.16195    0   82 5449.14050 5434.16195  0.27%     -    0s
# H    0     0                    5447.4861000 5434.16225  0.24%     -    0s
# H    0     0                    5443.5956000 5434.16225  0.17%     -    0s
#      0     0 5434.16225    0   82 5443.59560 5434.16225  0.17%     -    0s
# H    0     0                    5438.8003000 5434.16225  0.09%     -    0s
#      0     0 5436.28120    0   99 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.28120    0   54 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.28120    0   62 5438.80030 5436.28120  0.05%     -    0s
#      0     0 5436.46293    0   75 5438.80030 5436.46293  0.04%     -    0s
#      0     0          -    0      5438.80030 5438.33090  0.01%     -    0s
#
# Cutting planes:
#   Gomory: 4
#   MIR: 4
#   Zero half: 30
#   RLT: 4
#
# Explored 1 nodes (478 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 14 (of 14 available processors)
#
# Solution count 10: 5438.8 5438.8 5443.6 ... 6272.43
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.438800300000e+03, best bound 5.438330900000e+03, gap 0.0086%
# Discarded solution information
# Solving routing decisions...
# Set parameter TimeLimit to value 1800
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.1.0 23B2073)
#
# CPU model: Apple M3 Max
# Thread count: 14 physical cores, 14 logical processors, using up to 14 threads
#
# Optimize a model with 21807 rows, 49276 columns and 122409 nonzeros
# Model fingerprint: 0x33394527
# Variable types: 0 continuous, 49276 integer (49276 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e+02, 4e+04]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 773 rows and 705 columns
# Presolve time: 0.10s
# Presolved: 21034 rows, 48571 columns, 116524 nonzeros
# Variable types: 0 continuous, 48571 integer (48571 binary)
# Root relaxation presolved: 21034 rows, 48571 columns, 116524 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root relaxation: objective 5.371068e+04, 6986 iterations, 0.28 seconds (0.53 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 53710.6836    0  429          - 53710.6836      -     -    1s
# H    0     0                    88248.220000 53710.6836  39.1%     -    1s
#      0     0 69091.1163    0  457 88248.2200 69091.1163  21.7%     -    3s
# H    0     0                    85460.740000 69091.1163  19.2%     -    3s
#      0     0 69091.1163    0  734 85460.7400 69091.1163  19.2%     -    4s
#      0     0 69091.1163    0  734 85460.7400 69091.1163  19.2%     -    4s
#      0     0 69326.2598    0  544 85460.7400 69326.2598  18.9%     -    5s
#      0     0 69326.2598    0 1037 85460.7400 69326.2598  18.9%     -    6s
#      0     0 69326.2598    0 1018 85460.7400 69326.2598  18.9%     -    6s
#      0     0 69326.2598    0  689 85460.7400 69326.2598  18.9%     -    8s
#      0     0 69326.2598    0  703 85460.7400 69326.2598  18.9%     -    8s
#      0     0 69326.2598    0  597 85460.7400 69326.2598  18.9%     -    9s
#      0     0 69326.2598    0  697 85460.7400 69326.2598  18.9%     -    9s
#      0     0 69326.2598    0  695 85460.7400 69326.2598  18.9%     -    9s
#      0     0 69326.2598    0  633 85460.7400 69326.2598  18.9%     -   10s
#      0     0 69326.2598    0  633 85460.7400 69326.2598  18.9%     -   10s
#      0     2 69326.2598    0  588 85460.7400 69326.2598  18.9%     -   11s
#     15    26 70133.4612    4  626 85460.7400 69326.2598  18.9%  2154   15s
#    173   169 75265.0675   13  216 85460.7400 69326.2598  18.9%  1059   20s
#    300   265 71303.4975    8  369 85460.7400 69752.2075  18.4%   926   28s
#    371   303 72689.1325   11  133 85460.7400 69752.2075  18.4%   886   30s
#    574   440 70476.0764    9  467 85460.7400 69752.2075  18.4%   929  151s
#    883   631 71411.0387   20  506 85460.7400 69752.2075  18.4%   884  155s
#   1372   922 72907.9050   32  179 85460.7400 69752.2075  18.4%   819  160s
#   1810  1117 74004.0371   13  479 85460.7400 69752.2075  18.4%   777  171s
#   2056  1210 70670.4632   11  391 85460.7400 69889.3587  18.2%   760  175s
#   2674  1534 79167.6550   19  164 85460.7400 69889.3587  18.2%   763  180s
#   2939  1636 71515.3192   15  633 85460.7400 69889.3587  18.2%   775  185s
#   2941  1637 73553.6902   10  700 85460.7400 69889.3587  18.2%   774  190s
#   2944  1639 71128.2593   17  584 85460.7400 69889.3587  18.2%   773  195s
#   2949  1643 74161.9184   22  644 85460.7400 69889.3587  18.2%   772  200s
